# %%
import pandas as pd

# %%
df = pd.read_csv("ner_results_2021_2024_1.csv")

# %%
df.head()
# Out:
#                                              content
# 0  {'Both cigarettes and opioids are highly addic...
# 1  {'Deaths of despair have risen during the coro...
# 2  {'On March 1 the Supreme Court will hear argum...
# 3  {"Last year, the\xa0Centers for Disease Contro...
# 4  {'Part 1\xa0of a five-part USA TODAY series ex...

# %%
df = pd.read_csv("news_classified_2021_2024_2.csv")

# %%
df.shape
# Out:
# (252, 13)

# %%
df2["sentiment"].value_counts()
# Out:
# sentiment
# funding opportunity              69
# public policy and legislation    22
# drug use disorder                18
# prevention                       16
# medication-assisted treatment    13
# pharameutical industry           12
# overdose                         12
# misuse of pain medication        11
# lawsuit and settlement           10
# stigma                            9
# drug trafficking                  6
# addiction crisis                  6
# nalaxone                          3
# overdose reversal                 2
# medical malpractice               1
# opioid replacement                1
# international drug trade          1
# decriminalization                 1
# safe injection sites              1
# Name: count, dtype: int64

# %%
df2 = df[df["score"]> 0.2]

# %%
df2.shape
# Out:
# (214, 13)

# %%
df2.groupby("sentiment").mean("score")
# Out:
#                                   score
# sentiment
# addiction crisis               0.359005
# decriminalization              0.272503
# drug trafficking               0.415028
# drug use disorder              0.482713
# funding opportunity            0.731529
# international drug trade       0.397516
# lawsuit and settlement         0.501365
# medical malpractice            0.217781
# medication-assisted treatment  0.512438
# misuse of pain medication      0.426038
# nalaxone                       0.353225
# opioid replacement             0.405975
# overdose                       0.405347
# overdose reversal              0.265767
# pharameutical industry         0.445979
# prevention                     0.530069
# public policy and legislation  0.487525
# safe injection sites           0.536920
# stigma                         0.338451

# %%
cis = df[df["sentiment"]== "prevention"]

# %%
cis
# Out:
#                                                 author  \
# 21                          J. Wesley Boyd M.D., Ph.D.
# 36                          Claire Thornton, USA TODAY
# 37                             Danielle M. Dick, Ph.D.
# 39   Abdullah Shihipar, Alexandra B. Collins, and B...
# 61                                         Erin Prater
# 66                                        Chris Serres
# 74                                                 NaN
# 76                                                 NaN
# 78                                      MarketScreener
# 82                       Adrianna Rodriguez, USA TODAY
# 86                                                 NaN
# 88                                                 NaN
# 92                                                 NaN
# 104           USA TODAY, Christine Fernando, USA TODAY
# 110  Rena D'Souza, D.D.S., M.S., Ph.D., National In...
# 114                                      Stacey Colino
# ...
